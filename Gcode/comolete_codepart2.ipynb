# %%
api_key="AIzaSyA_0SnJOlLpD1I57kMS0NUrPjGQ1fMXcw0"

# %%
import googleapiclient.discovery
from googleapiclient.discovery import build
import pandas as pd

# %%
lf=pd.read_csv('MSSET9.csv',sep=",")  
lf
ids=[]
for i in range(len(lf)):
    ids.append((lf['VID'][i]))    
video_id = list(map(lambda x:x,ids))
video_id
# Out:
# ['lda3gBc3S1A',
#  'U0I25KZPgsQ',
#  'XTOEXAGB4UY',
#  'PUqtu1kIfKU',
#  'cv0hHeEHlbo',
#  'MxCVbISr21U',
#  'O0FI4bfhb7k',
#  '919ip9_urEo',
#  '5RBcIPuKDUc',
#  'Y1gA5aNLznM',
#  'Fl4QY5Cqtxc',
#  'ihQ1-LQOkns',
#  'MYZd8Rpzt9c',
#  '3ZRxXcE9mmQ',
#  'fmrxFcTTv-c',
#  'iX0Qvk7YbnU',
#  'yxRGm3ymVAk',
#  'YQRVvpytYic',
#  '6QO_PGr1Rso',
#  'HixMIKyUqSM']

# %%
from google_auth_oauthlib.flow import InstalledAppFlow
import googleapiclient.errors

# %%
CLIENT_SECRETS_FILE = "dk822.json"
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']

# %%
flow=InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE,SCOPES)
credentials=flow.run_console()
youtube=build('youtube','v3',credentials=credentials)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=145820979272-or57t80q2b7v5p1q0leekanlpuhe276r.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=6gN6MIHsK3fuOotD40IQNA5FtdLQRl&prompt=consent&access_type=offline
# Enter the authorization code: 4/ywEpPKYKEuasgDW2NQS9mRZGlIjeMBMO9OL7rgCC3acisvbIUv1k6jc

# %%
cat_name = [ ]
for i in range(len(video_id)):
      request = youtube.videos().list(part="snippet,contentDetails,statistics",id=video_id[i])
      response = request.execute()
      #print(response)
      m=response['items'][0]['snippet']['categoryId']
      #print(m)
      if m=="2":
        cat_name.append("Autos & Vehicles")
      if m=="1":
        cat_name.append("Film & Animation")
      if m=="10":
        cat_name.append("Music")
      if m=="15":
        cat_name.append("Pets & Animals")
      if m=="17":
        cat_name.append("Sports")
      if m=="18":
        cat_name.append("Short Movies")
      if m=="19":
        cat_name.append("Travel & Events")
      if m=="20":
        cat_name.append("Gaming")
      if m=="21":
        cat_name.append("Videoblogging")
      if m=="22":
        cat_name.append("People & Blogs")
      if m=="23":
        cat_name.append("Comedy")
      if m=="24":
        cat_name.append("Entertainment")
      if m=="25":
        cat_name.append("News & Politics")
      if m=="26":
        cat_name.append("Howto & Style")
      if m=="27":
        cat_name.append("Education")
      if m=="28":
        cat_name.append("Science & Technology")
      if m=="29":
        cat_name.append("Nonprofits & Activism")
      if m=="30":
        cat_name.append("Movies")
      if m=="31":
        cat_name.append("Anime/Animation")
      if m=="32":
        cat_name.append("Action/Adventure")
      if m=="33":
        cat_name.append("Classics")
      if m=="34":
        cat_name.append("Comedy")
      if m=="35":
        cat_name.append("Documentary")
      if m=="36":
        cat_name.append("Drama")
      if m=="37":
        cat_name.append("Family")
      if m=="38":
        cat_name.append("Foreign")
      if m=="39":
        cat_name.append("Horror")
      if m=="40":
        cat_name.append("Sci-Fi/Fantasy")
      if m=="41":
        cat_name.append("Thriller")
      if m=="42":
        cat_name.append("Shorts") 
      if m=="43":
        cat_name.append("Shows")
      if m=="44":
        cat_name.append("Trailers")
print(cat_name)
# Out:
# ['Entertainment', 'People & Blogs', 'News & Politics', 'Entertainment', 'Travel & Events', 'Science & Technology', 'News & Politics', 'People & Blogs', 'Music', 'Science & Technology', 'Gaming', 'News & Politics', 'People & Blogs', 'News & Politics', 'People & Blogs', 'Entertainment', 'News & Politics', 'People & Blogs', 'Pets & Animals', 'Pets & Animals']

# %%
import os
import googleapiclient.discovery
youtube = googleapiclient.discovery.build('youtube','v3', developerKey = api_key)
from googletrans import Translator

# %%
positive_polarity=[]
negative_polarity=[]
fakecomment=[]
for l in range(len(video_id)):
       comments_temp = []
       next_page_token = None
       ticker=0
       while 1:
             rest =youtube.commentThreads().list(part="snippet,replies",maxResults=100,order="relevance",textFormat="plainText",videoId=video_id[l],pageToken=next_page_token).execute()
             comments_temp += rest['items']
             next_page_token = rest.get('nextPageToken')
             if len(comments_temp)>=20:
                break    
             if next_page_token is None or ticker>=20:
                break
             ticker+=1
       com=[]
       for item in range(len(comments_temp)):
             com.append((comments_temp[item])['snippet']['topLevelComment']['snippet']['textDisplay'])
       for i in range(len(com)):
           try:
              trans=Translator()
              convertor=trans.translate(com[i]).text
              com[i]=convertor
           except:
              continue
              
       #lb={'comment':com}
       #lbs=pd.DataFrame(lb)
       #print(lbs)
       counter = 0        
       for i in range(len(com)):
             counter+=com[i].count('fake')
             counter+=com[i].count('Fake')
             counter+=com[i].count('FAKE')
             counter+=com[i].count('hoax')
             counter+=com[i].count('Hoax')
             counter+=com[i].count('HOAX')
             counter+=com[i].count('not true')
             counter+=com[i].count('Not true')
             counter+=com[i].count('NOT TRUE')
             counter+=com[i].count('Not True')
             counter+=com[i].count('False')
             counter+=com[i].count('false')
             counter+=com[i].count('FALSE')
             counter+=com[i].count('clickbait')
             counter+=com[i].count('CLICKBAIT')
             counter+=com[i].count('Clickbait')
             counter+=com[i].count('liar')
             counter+=com[i].count('Liar')
             counter+=com[i].count('LIAR')
             counter+=com[i].count('LIE')
             counter+=com[i].count('lie')
             counter+=com[i].count('Lie')
             counter+=com[i].count('Lied')
             counter+=com[i].count('lied')
             counter+=com[i].count('LIED')
             counter+=com[i].count('lying')
             counter+=com[i].count('Lying')
             counter+=com[i].count('LYING')
             counter+=com[i].count('WRONG INFORMATION')
             counter+=com[i].count('Wrong Information')
             counter+=com[i].count('wrong information')
             counter+=com[i].count('not real')
             counter+=com[i].count('Not Real')
             counter+=com[i].count('NOT REAL')
       fakecomment.append(counter)
       #print(counter)
       counter=0
       pol=[ ]
       count=0
       positive=0
       negative=0
       from textblob import TextBlob
       from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
       for i in range(len(com)):
            analysis=TextBlob(com[i])
            pol.append(analysis.sentiment.polarity)
            #print(analysis.sentiment.polarity)
            if analysis.sentiment.polarity <0.09:
                negative+=1
            if analysis.sentiment.polarity >=0.09:
                positive+=1
            count+=1 
       if negative==0:
           negative=1
       positive_polarity.append(positive)
       negative_polarity.append(negative)
       #print("POSITIVE RESPONSE = {}".format(positive))
       #print("NEGATIVE RESPONSE = {}".format(negative))

# %%
fakecomment
# Out:
# [0, 0, 0, 0, 0, 2, 2, 7, 1, 1, 0, 1, 1, 0, 1, 2, 14, 0, 0, 2]

# %%
stats = []
for i in range(0, len(video_id), 40):
   res = youtube.videos().list(id=','.join(video_id[i:i+40]),part='statistics').execute()
   stats += res['items']
#print(stats)

# %%
fortitle = []
for i in range(0, len(video_id), 40):
   rest = youtube.videos().list(id=','.join(video_id[i:i+40]),part='snippet').execute()
   fortitle+= rest['items']
#print(stats)

# %%
title=[ ]
liked=[ ]
disliked=[ ]
views=[ ]
comments=[ ]
ids=[ ]
dlratio =[ ]
compareposneg = [ ]
channelid=[ ]
subscribers = [ ]
date = [ ]
#video_id[0]

# %%
for i in range(len(video_id)):
      title.append((fortitle[i])['snippet']['title'])
      channelid.append((fortitle[i])['snippet']['channelId'])
      kara=int((stats[i])['statistics']['likeCount'])
      if kara==0:
            kara=1
      liked.append(kara)
      disliked.append(int((stats[i])['statistics']['dislikeCount']))
      dlratio.append(disliked[i]/liked[i])
      views.append(int((stats[i])['statistics']['viewCount']))
      comments.append(int((stats[i])['statistics']['commentCount']))
      compareposneg.append(positive_polarity[i]/negative_polarity[i])
                      
fakecomratio =[ ]     
for j in range(len(video_id)):
    if comments[j]<=200 and comments[j]>0:
        fakecomratio.append(fakecomment[j]/comments[j])
    if comments[j]>200:
        fakecomratio.append(fakecomment[j]/200)
    if comments[j]==0:
        fakecomratio.append(fakecomment[j]/1)

# %%
print(channelid)
# Out:
# ['UCLyKLLCNzdFotGKNL9mo8sQ', 'UCwZwI_kKptzBHU6FiA_95RA', 'UCAkC4RpTTgDG1kyDz0nQRxQ', 'UCVIQjvADa16atxzM4Bypm1g', 'UCSYp8LIuEABhztb0_KQTQ8Q', 'UCBhnEhLYn8angmvtQwfiaQg', 'UC-luje1qyKIAOFhts88E3Dw', 'UC5FT9ju8cHd_LkqHM7XpxXw', 'UCzySrhVKi3d6LtgscnyovBA', 'UCyf3mDk5O3s9gYIxdneeWQg', 'UC2DB95SoLuZFU_5lWPjE00Q', 'UCZj3_eWQ4f4oHm_x-wsxG7Q', 'UC3sEYMAZ8XNJbc7nhM2ihXA', 'UCu_sa2ZIHKkr5IXqUe7_VpQ', 'UC3VGfKd9ItwyVoaCwogj1cA', 'UC6QMuXTwMwJYIsYT6ybPKVw', 'UCpwvZwUam-URkxB7g4USKpg', 'UCwmK7lGImUYz4pb_z8XJytQ', 'UCTuZzdx0m3uVHv3hfwjEDsw', 'UC3339WgBDKIcxTfywuSmG8w']

# %%
for i in range(len(channelid)):
    request = youtube.channels().list(part="snippet,contentDetails,statistics",id=channelid[i]).execute()    
    s1=request['items'][0]['statistics']['subscriberCount']
    s2=request['items'][0]['snippet']['publishedAt'][:10]
    date.append(s2)
    subscribers.append(s1)

# %%
import pandas as pd
data={'title':title,'liked':liked,'disliked':disliked,'dlratio':dlratio,'subscriberCount':subscribers,'views':views,'comments':comments,'video_id':video_id,'positive_polarity':positive_polarity,'negative_polarity':negative_polarity,'compareposneg':compareposneg,'fakecomment':fakecomment,'fakecomratio':fakecomratio,'category':cat_name,'channel id':channelid,'registration':date}
df=pd.DataFrame(data)#title
df
# Out:
#                                                 title  liked  disliked  \
# 0   Personas Atrapadas en la Torre Grenfell en Lon...     95         1
# 1   German pensioners 'attacked by migrants after ...      8         3
# 2   British woman bargaining and shoot the Nepales...     40         6
# 3   2018-Bush cracks joke to Obama while Clinton m...      4        13
# 4   First Lady Melania Trump and Sara Netanyahu st...      1         2
# 5          Goat breaks into Argonics' Colorado office   9626       352
# 6   Michael Moore FULL Speech at Anti Trump NYC Pr...    142       158
# 7                      Sinead O'Connor Facebook Video   3651       500
# 8   Adele Medley - Casual Cover - Ronan Scolard & ...   2486        38
# 9   Ka-52 helicopter accidentally fires two S-8 ro...     86         9
# 10  Bloody Syrian boy (5-year-old boy Omran Daqnee...    165        17
# 11   Arrest of University Hospital nurse Alex Wubbels  23953      3845
# 12  French mounted police arrest motorcycle passenger    785        66
# 13  Опубликовано видео жестокого избиения врачей п...    265       166
# 14        Grain Bin Collapse and Grain Dust Explosion    670        31
# 15    Man Runs Over Abolish KKKolumbus Day protesters   4109      5872
# 16  Louvre attack: Mass evacuation following suspe...    209        14
# 17                      Baby Whale Shark Dubai Marina      1         1
# 18  Мужчина подрался с кенгуру, чтобы спасти свою ...      9         1
# 19             Bear Charges Car in Alaska || ViralHog   9140      1597
#
#      dlratio subscriberCount    views  comments     video_id  \
# 0   0.010526             731    12272         1  lda3gBc3S1A
# 1   0.375000               0     4345         3  U0I25KZPgsQ
# 2   0.150000              38     6315        58  XTOEXAGB4UY
# 3   3.250000               0     4223         3  PUqtu1kIfKU
# 4   2.000000              14      290         0  cv0hHeEHlbo
# 5   0.036568             449  2018890      2196  MxCVbISr21U
# 6   1.112676           16200    18789       122  O0FI4bfhb7k
# 7   0.136949             652   873170      3811  919ip9_urEo
# 8   0.015286             266   765233        98  5RBcIPuKDUc
# 9   0.104651            6360    37537        35  Y1gA5aNLznM
# 10  0.103030              46   119006       228  Fl4QY5Cqtxc
# 11  0.160523           24700  6576660     15292  ihQ1-LQOkns
# 12  0.084076              49   108292       217  MYZd8Rpzt9c
# 13  0.626415          404000   365387       432  3ZRxXcE9mmQ
# 14  0.046269              75   171865       131  fmrxFcTTv-c
# 15  1.429058               0  1791539      7199  iX0Qvk7YbnU
# 16  0.066986         3840000    12063       177  yxRGm3ymVAk
# 17  1.000000            1620      460         0  YQRVvpytYic
# 18  0.111111            1080     1441         0  6QO_PGr1Rso
# 19  0.174726          635000  2748739      1641  HixMIKyUqSM
#
#     positive_polarity  negative_polarity  compareposneg  fakecomment  \
# 0                   0                  1       0.000000            0
# 1                   0                  2       0.000000            0
# 2                   8                 11       0.727273            0
# 3                   0                  1       0.000000            0
# 4                   0                  1       0.000000            0
# 5                  31                 69       0.449275            2
# 6                  17                 39       0.435897            2
# 7                  70                 30       2.333333            7
# 8                  46                 21       2.190476            1
# 9                   4                 21       0.190476            1
# 10                 12                 53       0.226415            0
# 11                 33                 67       0.492537            1
# 12                 34                 59       0.576271            1
# 13                  3                 97       0.030928            0
# 14                 26                 44       0.590909            1
# 15                 48                 52       0.923077            2
# 16                 16                 39       0.410256           14
# 17                  0                  1       0.000000            0
# 18                  0                  1       0.000000            0
# 19                 28                 72       0.388889            2
#
#     fakecomratio              category                channel id registration
# 0       0.000000         Entertainment  UCLyKLLCNzdFotGKNL9mo8sQ   2016-05-14
# 1       0.000000        People & Blogs  UCwZwI_kKptzBHU6FiA_95RA   2016-01-05
# 2       0.000000       News & Politics  UCAkC4RpTTgDG1kyDz0nQRxQ   2012-11-17
# 3       0.000000         Entertainment  UCVIQjvADa16atxzM4Bypm1g   2017-10-13
# 4       0.000000       Travel & Events  UCSYp8LIuEABhztb0_KQTQ8Q   2016-04-29
# 5       0.010000  Science & Technology  UCBhnEhLYn8angmvtQwfiaQg   2012-03-27
# 6       0.016393       News & Politics  UC-luje1qyKIAOFhts88E3Dw   2015-03-17
# 7       0.035000        People & Blogs  UC5FT9ju8cHd_LkqHM7XpxXw   2017-08-05
# 8       0.010204                 Music  UCzySrhVKi3d6LtgscnyovBA   2009-01-01
# 9       0.028571  Science & Technology  UCyf3mDk5O3s9gYIxdneeWQg   2014-01-17
# 10      0.000000                Gaming  UC2DB95SoLuZFU_5lWPjE00Q   2016-06-28
# 11      0.005000       News & Politics  UCZj3_eWQ4f4oHm_x-wsxG7Q   2006-10-31
# 12      0.005000        People & Blogs  UC3sEYMAZ8XNJbc7nhM2ihXA   2013-08-17
# 13      0.000000       News & Politics  UCu_sa2ZIHKkr5IXqUe7_VpQ   2014-10-31
# 14      0.007634        People & Blogs  UC3VGfKd9ItwyVoaCwogj1cA   2008-12-05
# 15      0.010000         Entertainment  UC6QMuXTwMwJYIsYT6ybPKVw   2015-11-03
# 16      0.079096       News & Politics  UCpwvZwUam-URkxB7g4USKpg   2007-03-28
# 17      0.000000        People & Blogs  UCwmK7lGImUYz4pb_z8XJytQ   2015-11-02
# 18      0.000000        Pets & Animals  UCTuZzdx0m3uVHv3hfwjEDsw   2011-06-08
# 19      0.010000        Pets & Animals  UC3339WgBDKIcxTfywuSmG8w   2014-08-22

# %%
df.to_csv('MSRESULT9.csv',index=False)
