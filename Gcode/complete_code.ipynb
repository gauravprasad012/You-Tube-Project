# %%
api_key="AIzaSyDknjffnFimwejR1BozIjL4uut7dFOoA7A"

# %%
import googleapiclient.discovery
from googleapiclient.discovery import build
import pandas as pd

# %%
lf=pd.read_csv('us9.csv',sep=",")  
lf
ids=[]
for i in range(len(lf)):
    ids.append((lf['VID'][i]))    
video_id = list(map(lambda x:x,ids))
video_id
# Out:
# ['c0P5tAY3Prw',
#  'jMdkaIj4i4g',
#  'E4FM9WGRWdQ',
#  'gPtfxrTToFQ',
#  'JrS_b9qpHs8',
#  'Ju7g-rYFS-o',
#  'ufn36GEMSLc',
#  '_w2r5ulX288',
#  '7iK2K160WyE',
#  'I_3mAjgu4II',
#  'CxDmXO-Nf7k',
#  'mBcUas2lKrY',
#  'pCG-dLk0U14',
#  'Nud51EZDZ7I',
#  'NXJMWwSICHg',
#  'uOFQkkwqpEE',
#  'hF0lvj5K0UM',
#  'bwYuPIslAVY',
#  'ywnzZvJNdGE',
#  'ZZC80cSalHI',
#  'bOfzQnMvEpQ',
#  'Fn5DGOJC07g',
#  'rTjl3ZdPh-M',
#  'X-eshuBV04E',
#  'WzItssvxm4k',
#  'DVt4b07V3mE',
#  'm0Ecjse80-U',
#  'zK1bcLgdlfw',
#  'k6PxMRUgmbA']

# %%
from google_auth_oauthlib.flow import InstalledAppFlow
import googleapiclient.errors

# %%
CLIENT_SECRETS_FILE = "dk823.json"
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']

# %%
flow=InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE,SCOPES)
credentials=flow.run_console()
youtube=build('youtube','v3',credentials=credentials)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=209204083876-o4lrfmoi89c29qk014klmngt4hces33a.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=9dZ07wN5C5Ssj9YwYyvXusntRJDCGz&prompt=consent&access_type=offline
# Enter the authorization code: 4/1QGkV9S6HCmPotc55UH7d9wNWUuZYDRiQ5E505r4vHc4cY20DEr0KiI

# %%
cat_name = [ ]
for i in range(len(video_id)):
      request = youtube.videos().list(part="snippet,contentDetails,statistics",id=video_id[i])
      response = request.execute()
      #print(response)
      m=response['items'][0]['snippet']['categoryId']
      #print(m)
      if m=="2":
        cat_name.append("Autos & Vehicles")
      if m=="1":
        cat_name.append("Film & Animation")
      if m=="10":
        cat_name.append("Music")
      if m=="15":
        cat_name.append("Pets & Animals")
      if m=="17":
        cat_name.append("Sports")
      if m=="18":
        cat_name.append("Short Movies")
      if m=="19":
        cat_name.append("Travel & Events")
      if m=="20":
        cat_name.append("Gaming")
      if m=="21":
        cat_name.append("Videoblogging")
      if m=="22":
        cat_name.append("People & Blogs")
      if m=="23":
        cat_name.append("Comedy")
      if m=="24":
        cat_name.append("Entertainment")
      if m=="25":
        cat_name.append("News & Politics")
      if m=="26":
        cat_name.append("Howto & Style")
      if m=="27":
        cat_name.append("Education")
      if m=="28":
        cat_name.append("Science & Technology")
      if m=="29":
        cat_name.append("Nonprofits & Activism")
      if m=="30":
        cat_name.append("Movies")
      if m=="31":
        cat_name.append("Anime/Animation")
      if m=="32":
        cat_name.append("Action/Adventure")
      if m=="33":
        cat_name.append("Classics")
      if m=="34":
        cat_name.append("Comedy")
      if m=="35":
        cat_name.append("Documentary")
      if m=="36":
        cat_name.append("Drama")
      if m=="37":
        cat_name.append("Family")
      if m=="38":
        cat_name.append("Foreign")
      if m=="39":
        cat_name.append("Horror")
      if m=="40":
        cat_name.append("Sci-Fi/Fantasy")
      if m=="41":
        cat_name.append("Thriller")
      if m=="42":
        cat_name.append("Shorts") 
      if m=="43":
        cat_name.append("Shows")
      if m=="44":
        cat_name.append("Trailers")
print(cat_name)
# Out:
# ['News & Politics', 'News & Politics', 'People & Blogs', 'Science & Technology', 'Sports', 'Sports', 'People & Blogs', 'Entertainment', 'Sports', 'Entertainment', 'People & Blogs', 'People & Blogs', 'People & Blogs', 'People & Blogs', 'Entertainment', 'Comedy', 'Comedy', 'Science & Technology', 'Pets & Animals', 'Gaming', 'Entertainment', 'Film & Animation', 'Comedy', 'News & Politics', 'Autos & Vehicles', 'People & Blogs', 'People & Blogs', 'News & Politics', 'Music']

# %%
import os
import googleapiclient.discovery
youtube = googleapiclient.discovery.build('youtube','v3', developerKey = api_key)
from googletrans import Translator

# %%
positive_polarity=[]
negative_polarity=[]
fakecomment=[]
for l in range(len(video_id)):
       comments_temp = []
       next_page_token = None
       ticker=0
       while 1:
             rest =youtube.commentThreads().list(part="snippet,replies",maxResults=100,order="relevance",textFormat="plainText",videoId=video_id[l],pageToken=next_page_token).execute()
             comments_temp += rest['items']
             next_page_token = rest.get('nextPageToken')
             if len(comments_temp)>=20:
                break    
             if next_page_token is None or ticker>=20:
                break
             ticker+=1
       com=[]
       for item in range(len(comments_temp)):
             com.append((comments_temp[item])['snippet']['topLevelComment']['snippet']['textDisplay'])
       for i in range(len(com)):
           try:
              trans=Translator()
              convertor=trans.translate(com[i]).text
              com[i]=convertor
           except:
              continue
              
       #lb={'comment':com}
       #lbs=pd.DataFrame(lb)
       #print(lbs)
       counter = 0        
       for i in range(len(com)):
             counter+=com[i].count('fake')
             counter+=com[i].count('Fake')
             counter+=com[i].count('FAKE')
             counter+=com[i].count('hoax')
             counter+=com[i].count('Hoax')
             counter+=com[i].count('HOAX')
             counter+=com[i].count('not true')
             counter+=com[i].count('Not true')
             counter+=com[i].count('NOT TRUE')
             counter+=com[i].count('Not True')
             counter+=com[i].count('False')
             counter+=com[i].count('false')
             counter+=com[i].count('FALSE')
             counter+=com[i].count('clickbait')
             counter+=com[i].count('CLICKBAIT')
             counter+=com[i].count('Clickbait')
             counter+=com[i].count('liar')
             counter+=com[i].count('Liar')
             counter+=com[i].count('LIAR')
             counter+=com[i].count('LIE')
             counter+=com[i].count('lie')
             counter+=com[i].count('Lie')
             counter+=com[i].count('Lied')
             counter+=com[i].count('lied')
             counter+=com[i].count('LIED')
             counter+=com[i].count('lying')
             counter+=com[i].count('Lying')
             counter+=com[i].count('LYING')
             counter+=com[i].count('WRONG INFORMATION')
             counter+=com[i].count('Wrong Information')
             counter+=com[i].count('wrong information')
             counter+=com[i].count('not real')
             counter+=com[i].count('Not Real')
             counter+=com[i].count('NOT REAL')
       fakecomment.append(counter)
       #print(counter)
       counter=0
       pol=[ ]
       count=0
       positive=0
       negative=0
       from textblob import TextBlob
       from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
       for i in range(len(com)):
            analysis=TextBlob(com[i])
            pol.append(analysis.sentiment.polarity)
            #print(analysis.sentiment.polarity)
            if analysis.sentiment.polarity <0.09:
                negative+=1
            if analysis.sentiment.polarity >=0.09:
                positive+=1
            count+=1 
       if negative==0:
           negative=1
       positive_polarity.append(positive)
       negative_polarity.append(negative)
       #print("POSITIVE RESPONSE = {}".format(positive))
       #print("NEGATIVE RESPONSE = {}".format(negative))

# %%
stats = []
for i in range(0, len(video_id), 40):
   res = youtube.videos().list(id=','.join(video_id[i:i+40]),part='statistics').execute()
   stats += res['items']
#print(stats)

# %%
fortitle = []
for i in range(0, len(video_id), 40):
   rest = youtube.videos().list(id=','.join(video_id[i:i+40]),part='snippet').execute()
   fortitle+= rest['items']
#print(stats)

# %%
title=[ ]
liked=[ ]
disliked=[ ]
views=[ ]
comments=[ ]
ids=[ ]
dlratio =[ ]
compareposneg = [ ]
channelid=[ ]
subscribers = [ ]
date = [ ]
#video_id[0]

# %%
for i in range(len(video_id)):
      title.append((fortitle[i])['snippet']['title'])
      channelid.append((fortitle[i])['snippet']['channelId'])
      kara=int((stats[i])['statistics']['likeCount'])
      if kara==0:
            kara=1
      liked.append(kara)
      disliked.append(int((stats[i])['statistics']['dislikeCount']))
      dlratio.append(disliked[i]/liked[i])
      views.append(int((stats[i])['statistics']['viewCount']))
      comments.append(int((stats[i])['statistics']['commentCount']))
      compareposneg.append(positive_polarity[i]/negative_polarity[i])
                      
fakecomratio =[ ]     
for j in range(len(video_id)):
    if comments[j]<=200 and comments[j]>0:
        fakecomratio.append(fakecomment[j]/comments[j])
    if comments[j]>200:
        fakecomratio.append(fakecomment[j]/200)
    if comments[j]==0:
        fakecomratio.append(fakecomment[j]/1)

# %%
print(channelid)
channel_views = [ ]
channel_title = [ ]
channel_totalvideo=[ ]
# Out:
# ['UC9c8wy5g1usCLdEaf-2mB3A', 'UCMC0QEkK0FCteaC0QWP2H5g', 'UCxGHcGWvEBKPvmvHNujtyLg', 'UCfB8ETL2eSlmJHOJL_wE8cw', 'UClG67VaQKaMetU5obWqJcqg', 'UCn_AsClJjokJmndorYEzG1Q', 'UCxf8FqshhoHo5XSsMCePrSw', 'UCfYIUy2_-TEUnPl_442ntXA', 'UCblfuW_4rakIf2h6aqANefA', 'UCgAP0QciMsZK0s-dhnvACuw', 'UCe48u-h6bQzfRrEE_xJbY9w', 'UCe48u-h6bQzfRrEE_xJbY9w', 'UCjBHJUpdEEvoah6edh0KtVA', 'UCkvO6KQMNO_kwTgAzCU4Agg', 'UCtjpWwEEpmzlP4hNkLLsruQ', 'UCtKf_mQKvfiPvpxyKBVWBoQ', 'UCUXE0CTYAXMco8h68x9S1iw', 'UC8Cu8yNUiHcj9nUAac5IwiA', 'UCBBBeZrFURUl4XR-NnEyEVw', 'UC_s6xxmTMKThAUyXlXexDRg', 'UC3R16m76z5qOnFLW3v0phhw', 'UCPLmTpMKProBdOwEOno_sSw', 'UCsqoAMvRYBjbDHiVlAtbERQ', 'UCjOrvl6otWd17dudu4q1hhA', 'UClkCaZEcihIQQA9RifGGE9g', 'UCLT6sSKaeWYgI5OIYen1YcQ', 'UCMDUZksDo4s6E3xArnVu0yw', 'UC5aeU5hk31cLzq_sAExLVWg', 'UCtccbWvR1RQb976Jo6Mt7Yw']

# %%
for i in range(len(channelid)):
    request = youtube.channels().list(part="snippet,contentDetails,statistics",id=channelid[i]).execute()    
    s1=request['items'][0]['statistics']['subscriberCount']
    s2=request['items'][0]['snippet']['publishedAt'][:10]
    channel_title.append(request['items'][0]['snippet']['title'])
    channel_views.append(int(request['items'][0]['statistics']['viewCount']))
    channel_totalvideo.append(int(request['items'][0]['statistics']['videoCount']))
    date.append(s2)
    subscribers.append(s1)

# %%
#print((fortitle[0])['snippet']['title'])

# %%
import pandas as pd
data={'title':title,'liked':liked,'disliked':disliked,'dlratio':dlratio,'subscriberCount':subscribers,'views':views,'comments':comments,'video_id':video_id,'positive_polarity':positive_polarity,'negative_polarity':negative_polarity,'compareposneg':compareposneg,'fakecomment':fakecomment,'fakecomratio':fakecomratio,'category':cat_name,'channel id':channelid,'registration':date,'channel_title':channel_title,'channel_views':channel_views,'channel_totalvideo':channel_totalvideo}
df=pd.DataFrame(data)#title
df
# Out:
#                                                 title   liked  disliked  \
# 0   Dramatic moment North Korean soldier makes mad...       1         0
# 1   Dramatic moment North Korean soldier makes mad...       1         0
# 2   Brave Palestinian girl Ahed Tamimi vs Soldier ...    3347       798
# 3   Angry people throwing stones on Mumbai local t...       9         3
# 4   GoPro: Backflip Over 72ft Canyon - Kelly McGar...      11         3
# 5   GoPro: Backflip Over 72ft Canyon - Kelly McGar...       4         0
# 6               GoPro Kelly McGarry remix w/ Zero Sum       2         0
# 7   GoPro  Red Bull Rampage   Kelly McGarry   Back...       2         0
# 8   Kelly McGarry's 72ft Canyon Gap POV - Red Bull...   10221       208
# 9   Незабываемый спуск по каньону  GoPro  Backflip...       1         0
# 10  GoPro  Backflip Over 72ft Canyon   Kelly McGar...       1         0
# 11  GoPro  Backflip Over 72ft Canyon   Kelly McGar...       1         0
# 12  Downhill Mountain - Kelly McGarry Red Bull Ram...       7         0
# 13  VR - SBS - GoPro Backflip Over 72ft Canyon   K...       8         2
# 14             Weather Reporter Gets Hit By Stop Sign   27288       751
# 15          GRANT A WISH KID'S TOUCHDOWN GETS DENIED!  411296     14917
# 16                                   MLG Grant A Wish       9         5
# 17                             Sub-Aquatic Detonation       6         0
# 18  Sun Bear I Dangerous Sun Bear Captured Near Ke...       9         2
# 19  Man eating animal caught at Kerala Karnataka b...     149        48
# 20  Amazing airborne view of rolling clouds around...      30         4
# 21  я в шоке, такого я ещё не видел , дельфин и со...     181        10
# 22  Car dropped down the stairs of the subway in B...       5         3
# 23  Thugs push a car in subway stairs at metro cle...       7        30
# 24  Insane guy throws car down Subway Stairs -MUST...      11         1
# 25                   Insane Riot in Brussels, Belgium       2         0
# 26                      Putin and pigeon. Putin style      31         4
# 27  Russia: Coo-Coo! - Putin blanked by pigeon at ...    3665       276
# 28  29 Celebrity Impressions, 1 Original Song - Ro...  277788     12693
#
#      dlratio subscriberCount     views  comments     video_id  \
# 0   0.000000             131        42         0  c0P5tAY3Prw
# 1   0.000000               7        26         0  jMdkaIj4i4g
# 2   0.238422            1410    682522      2621  E4FM9WGRWdQ
# 3   0.333333               0       517         2  gPtfxrTToFQ
# 4   0.272727               3      2605         0  JrS_b9qpHs8
# 5   0.000000               2      1094         0  Ju7g-rYFS-o
# 6   0.000000              32       273         0  ufn36GEMSLc
# 7   0.000000              32        79         0  _w2r5ulX288
# 8   0.020350         9450000   1914508       969  7iK2K160WyE
# 9   0.000000               0        88         0  I_3mAjgu4II
# 10  0.000000               0        29         0  CxDmXO-Nf7k
# 11  0.000000               0        88         0  mBcUas2lKrY
# 12  0.000000           41400       671         0  pCG-dLk0U14
# 13  0.250000              11      3063         0  Nud51EZDZ7I
# 14  0.027521            1130   1263084      3692  NXJMWwSICHg
# 15  0.036268         3380000  20462424     51302  uOFQkkwqpEE
# 16  0.555556              33       552         2  hF0lvj5K0UM
# 17  0.000000             157       217         0  bwYuPIslAVY
# 18  0.222222              56      1772         4  ywnzZvJNdGE
# 19  0.322148               0     39462        19  ZZC80cSalHI
# 20  0.133333             269     10438         6  bOfzQnMvEpQ
# 21  0.055249             981     14694         8  Fn5DGOJC07g
# 22  0.600000               9     12238         0  rTjl3ZdPh-M
# 23  4.285714              32     24880         2  X-eshuBV04E
# 24  0.090909               0       609         0  WzItssvxm4k
# 25  0.000000              19       261         1  DVt4b07V3mE
# 26  0.129032              10      6944         1  m0Ecjse80-U
# 27  0.075307         1300000    826169       361  zK1bcLgdlfw
# 28  0.045693          308000  18603530     17493  k6PxMRUgmbA
#
#     positive_polarity  negative_polarity  compareposneg  fakecomment  \
# 0                   0                  1       0.000000            0
# 1                   0                  1       0.000000            0
# 2                  32                 68       0.470588            0
# 3                   1                  1       1.000000            0
# 4                   0                  1       0.000000            0
# 5                   0                  1       0.000000            0
# 6                   0                  1       0.000000            0
# 7                   0                  1       0.000000            0
# 8                  37                 63       0.587302            1
# 9                   0                  1       0.000000            0
# 10                  0                  1       0.000000            0
# 11                  0                  1       0.000000            0
# 12                  0                  1       0.000000            0
# 13                  0                  1       0.000000            0
# 14                 40                 60       0.666667            5
# 15                 31                 69       0.449275            7
# 16                  0                  2       0.000000            0
# 17                  0                  1       0.000000            0
# 18                  0                  3       0.000000            0
# 19                  5                  7       0.714286            6
# 20                  3                  2       1.500000            0
# 21                  0                  7       0.000000            0
# 22                  0                  1       0.000000            0
# 23                  0                  2       0.000000            0
# 24                  0                  1       0.000000            0
# 25                  0                  1       0.000000            0
# 26                  1                  1       1.000000            0
# 27                 32                 68       0.470588           14
# 28                 50                 50       1.000000           24
#
#     fakecomratio              category                channel id registration  \
# 0       0.000000       News & Politics  UC9c8wy5g1usCLdEaf-2mB3A   2009-09-02
# 1       0.000000       News & Politics  UCMC0QEkK0FCteaC0QWP2H5g   2016-11-24
# 2       0.000000        People & Blogs  UCxGHcGWvEBKPvmvHNujtyLg   2011-09-20
# 3       0.000000  Science & Technology  UCfB8ETL2eSlmJHOJL_wE8cw   2017-08-25
# 4       0.000000                Sports  UClG67VaQKaMetU5obWqJcqg   2012-07-23
# 5       0.000000                Sports  UCn_AsClJjokJmndorYEzG1Q   2013-10-23
# 6       0.000000        People & Blogs  UCxf8FqshhoHo5XSsMCePrSw   2013-09-19
# 7       0.000000         Entertainment  UCfYIUy2_-TEUnPl_442ntXA   2013-06-01
# 8       0.005000                Sports  UCblfuW_4rakIf2h6aqANefA   2006-09-23
# 9       0.000000         Entertainment  UCgAP0QciMsZK0s-dhnvACuw   2012-10-16
# 10      0.000000        People & Blogs  UCe48u-h6bQzfRrEE_xJbY9w   2014-04-17
# 11      0.000000        People & Blogs  UCe48u-h6bQzfRrEE_xJbY9w   2014-04-17
# 12      0.000000        People & Blogs  UCjBHJUpdEEvoah6edh0KtVA   2014-09-23
# 13      0.000000        People & Blogs  UCkvO6KQMNO_kwTgAzCU4Agg   2015-09-27
# 14      0.025000         Entertainment  UCtjpWwEEpmzlP4hNkLLsruQ   2015-06-26
# 15      0.035000                Comedy  UCtKf_mQKvfiPvpxyKBVWBoQ   2011-11-24
# 16      0.000000                Comedy  UCUXE0CTYAXMco8h68x9S1iw   2015-04-10
# 17      0.000000  Science & Technology  UC8Cu8yNUiHcj9nUAac5IwiA   2013-11-18
# 18      0.000000        Pets & Animals  UCBBBeZrFURUl4XR-NnEyEVw   2016-11-07
# 19      0.315789                Gaming  UC_s6xxmTMKThAUyXlXexDRg   2015-10-25
# 20      0.000000         Entertainment  UC3R16m76z5qOnFLW3v0phhw   2011-04-01
# 21      0.000000      Film & Animation  UCPLmTpMKProBdOwEOno_sSw   2015-05-30
# 22      0.000000                Comedy  UCsqoAMvRYBjbDHiVlAtbERQ   2007-09-10
# 23      0.000000       News & Politics  UCjOrvl6otWd17dudu4q1hhA   2015-06-24
# 24      0.000000      Autos & Vehicles  UClkCaZEcihIQQA9RifGGE9g   2016-01-03
# 25      0.000000        People & Blogs  UCLT6sSKaeWYgI5OIYen1YcQ   2015-12-06
# 26      0.000000        People & Blogs  UCMDUZksDo4s6E3xArnVu0yw   2017-05-30
# 27      0.070000       News & Politics  UC5aeU5hk31cLzq_sAExLVWg   2012-11-06
# 28      0.120000                 Music  UCtccbWvR1RQb976Jo6Mt7Yw   2013-10-23
#
#                             channel_title  channel_views  channel_totalvideo
# 0                           Sheva Permana          59521                  30
# 1   My Love 4 You United States Air Force           2181                  66
# 2                              Nokta Grup        3379668                  74
# 3                            Technical KK          11730                  80
# 4                               youppi go           2674                   2
# 5                             madara simo           1258                   2
# 6                        Our Wild America           5593                  24
# 7                         Step2event team          27241                  62
# 8                                Red Bull     2245710745                5453
# 9                              Lacidofeel          28494                  33
# 10                                 sports            495                  11
# 11                                 sports            495                  11
# 12                             Kaiowas 73       24692055                 134
# 13                     ELTON - SCVGE 08RS           4551                  13
# 14                            Sidemen 360        1293259                   2
# 15                   LifeAccordingToJimmy      629090435                 266
# 16                        Radi0activeMnky           8035                   6
# 17                             Hell Yeah!         153799                  23
# 18                                KTS fun           4102                   9
# 19                                 IND DT        1056270                  79
# 20          Weather and Nature Enthusiast         323067                 212
# 21                          Oleg ПОСМОТРИ         357670                   4
# 22                                vincent          55990                   7
# 23                           Sárga liliom         167665                  33
# 24                             Live Share           1023                   3
# 25                           kölsche jung          30092                   2
# 26                        Наша Пропаганда           7508                   3
# 27                                 Ruptly     1008864499              104020
# 28                              robcantor       96034116                  12

# %%
df.to_csv('resultus9.csv',index=False)
