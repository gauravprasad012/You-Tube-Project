# %%
api_key="AIzaSyDKrUJRaFUg08wGRTMR5phFdow4paIoteg"

# %%
import googleapiclient.discovery
from googleapiclient.discovery import build
import pandas as pd

# %%
lf=pd.read_csv('MSSET10.csv',sep=",")  
lf
ids=[]
for i in range(len(lf)):
    ids.append((lf['VID'][i]))    
video_id = list(map(lambda x:x,ids))
video_id
# Out:
# ['izNDNHK3_N8',
#  'c0ztLtpuwkM',
#  'aWpFxEmtIDA',
#  't9kfJUQnawU',
#  '0fNy_tWYkd4',
#  't9kfJUQnawU',
#  'XvMoYEUVcB4',
#  'lYFpga7kJxE',
#  'WNjFFTQsIAg',
#  'x76VEPXYaI0',
#  'VESBrSWm3Yg']

# %%
from google_auth_oauthlib.flow import InstalledAppFlow
import googleapiclient.errors

# %%
CLIENT_SECRETS_FILE = "diveshk977.json"
SCOPES = ['https://www.googleapis.com/auth/youtube.force-ssl']

# %%
flow=InstalledAppFlow.from_client_secrets_file(CLIENT_SECRETS_FILE,SCOPES)
credentials=flow.run_console()
youtube=build('youtube','v3',credentials=credentials)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=17262471643-9q1lqel2244jmj0c0g1tf8non3l9pj2t.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fyoutube.force-ssl&state=Tz6etS2JpDTX623VkIIGEmKhdTAcLl&prompt=consent&access_type=offline
# Enter the authorization code: 4/ywH6fLuJ2QpJ2HCzgSX7yZmFtpPYFSTUsVaQd0xQVkDypueK0feUxqk

# %%
cat_name = [ ]
for i in range(len(video_id)):
      request = youtube.videos().list(part="snippet,contentDetails,statistics",id=video_id[i])
      response = request.execute()
      #print(response)
      m=response['items'][0]['snippet']['categoryId']
      #print(m)
      if m=="2":
        cat_name.append("Autos & Vehicles")
      if m=="1":
        cat_name.append("Film & Animation")
      if m=="10":
        cat_name.append("Music")
      if m=="15":
        cat_name.append("Pets & Animals")
      if m=="17":
        cat_name.append("Sports")
      if m=="18":
        cat_name.append("Short Movies")
      if m=="19":
        cat_name.append("Travel & Events")
      if m=="20":
        cat_name.append("Gaming")
      if m=="21":
        cat_name.append("Videoblogging")
      if m=="22":
        cat_name.append("People & Blogs")
      if m=="23":
        cat_name.append("Comedy")
      if m=="24":
        cat_name.append("Entertainment")
      if m=="25":
        cat_name.append("News & Politics")
      if m=="26":
        cat_name.append("Howto & Style")
      if m=="27":
        cat_name.append("Education")
      if m=="28":
        cat_name.append("Science & Technology")
      if m=="29":
        cat_name.append("Nonprofits & Activism")
      if m=="30":
        cat_name.append("Movies")
      if m=="31":
        cat_name.append("Anime/Animation")
      if m=="32":
        cat_name.append("Action/Adventure")
      if m=="33":
        cat_name.append("Classics")
      if m=="34":
        cat_name.append("Comedy")
      if m=="35":
        cat_name.append("Documentary")
      if m=="36":
        cat_name.append("Drama")
      if m=="37":
        cat_name.append("Family")
      if m=="38":
        cat_name.append("Foreign")
      if m=="39":
        cat_name.append("Horror")
      if m=="40":
        cat_name.append("Sci-Fi/Fantasy")
      if m=="41":
        cat_name.append("Thriller")
      if m=="42":
        cat_name.append("Shorts") 
      if m=="43":
        cat_name.append("Shows")
      if m=="44":
        cat_name.append("Trailers")
print(cat_name)
# Out:
# ['News & Politics', 'People & Blogs', 'Entertainment', 'Comedy', 'News & Politics', 'Comedy', 'People & Blogs', 'News & Politics', 'News & Politics', 'Sports', 'People & Blogs']

# %%
import os
import googleapiclient.discovery
youtube = googleapiclient.discovery.build('youtube','v3', developerKey = api_key)
from googletrans import Translator

# %%
positive_polarity=[]
negative_polarity=[]
fakecomment=[]
for l in range(len(video_id)):
       comments_temp = []
       next_page_token = None
       ticker=0
       while 1:
             rest =youtube.commentThreads().list(part="snippet,replies",maxResults=100,order="relevance",textFormat="plainText",videoId=video_id[l],pageToken=next_page_token).execute()
             comments_temp += rest['items']
             next_page_token = rest.get('nextPageToken')
             if len(comments_temp)>=20:
                break    
             if next_page_token is None or ticker>=20:
                break
             ticker+=1
       com=[]
       for item in range(len(comments_temp)):
             com.append((comments_temp[item])['snippet']['topLevelComment']['snippet']['textDisplay'])
       for i in range(len(com)):
           try:
              trans=Translator()
              convertor=trans.translate(com[i]).text
              com[i]=convertor
           except:
              continue
              
       #lb={'comment':com}
       #lbs=pd.DataFrame(lb)
       #print(lbs)
       counter = 0        
       for i in range(len(com)):
             counter+=com[i].count('fake')
             counter+=com[i].count('Fake')
             counter+=com[i].count('FAKE')
             counter+=com[i].count('hoax')
             counter+=com[i].count('Hoax')
             counter+=com[i].count('HOAX')
             counter+=com[i].count('not true')
             counter+=com[i].count('Not true')
             counter+=com[i].count('NOT TRUE')
             counter+=com[i].count('Not True')
             counter+=com[i].count('False')
             counter+=com[i].count('false')
             counter+=com[i].count('FALSE')
             counter+=com[i].count('clickbait')
             counter+=com[i].count('CLICKBAIT')
             counter+=com[i].count('Clickbait')
             counter+=com[i].count('liar')
             counter+=com[i].count('Liar')
             counter+=com[i].count('LIAR')
             counter+=com[i].count('LIE')
             counter+=com[i].count('lie')
             counter+=com[i].count('Lie')
             counter+=com[i].count('Lied')
             counter+=com[i].count('lied')
             counter+=com[i].count('LIED')
             counter+=com[i].count('lying')
             counter+=com[i].count('Lying')
             counter+=com[i].count('LYING')
             counter+=com[i].count('WRONG INFORMATION')
             counter+=com[i].count('Wrong Information')
             counter+=com[i].count('wrong information')
             counter+=com[i].count('not real')
             counter+=com[i].count('Not Real')
             counter+=com[i].count('NOT REAL')
       fakecomment.append(counter)
       #print(counter)
       counter=0
       pol=[ ]
       count=0
       positive=0
       negative=0
       from textblob import TextBlob
       from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
       for i in range(len(com)):
            analysis=TextBlob(com[i])
            pol.append(analysis.sentiment.polarity)
            #print(analysis.sentiment.polarity)
            if analysis.sentiment.polarity <0.09:
                negative+=1
            if analysis.sentiment.polarity >=0.09:
                positive+=1
            count+=1 
       if negative==0:
           negative=1
       positive_polarity.append(positive)
       negative_polarity.append(negative)
       #print("POSITIVE RESPONSE = {}".format(positive))
       #print("NEGATIVE RESPONSE = {}".format(negative))

# %%
fakecomment
# Out:
# [2, 2, 0, 2, 7, 2, 0, 0, 0, 0, 0]

# %%
stats = []
for i in range(0, len(video_id), 40):
   res = youtube.videos().list(id=','.join(video_id[i:i+40]),part='statistics').execute()
   stats += res['items']
#print(stats)

# %%
fortitle = []
for i in range(0, len(video_id), 40):
   rest = youtube.videos().list(id=','.join(video_id[i:i+40]),part='snippet').execute()
   fortitle+= rest['items']
#print(stats)

# %%
title=[ ]
liked=[ ]
disliked=[ ]
views=[ ]
comments=[ ]
ids=[ ]
dlratio =[ ]
compareposneg = [ ]
channelid=[ ]
subscribers = [ ]
date = [ ]
#video_id[0]

# %%
for i in range(len(video_id)):
      title.append((fortitle[i])['snippet']['title'])
      channelid.append((fortitle[i])['snippet']['channelId'])
      kara=int((stats[i])['statistics']['likeCount'])
      if kara==0:
            kara=1
      liked.append(kara)
      disliked.append(int((stats[i])['statistics']['dislikeCount']))
      dlratio.append(disliked[i]/liked[i])
      views.append(int((stats[i])['statistics']['viewCount']))
      comments.append(int((stats[i])['statistics']['commentCount']))
      compareposneg.append(positive_polarity[i]/negative_polarity[i])
                      
fakecomratio =[ ]     
for j in range(len(video_id)):
    if comments[j]<=200 and comments[j]>0:
        fakecomratio.append(fakecomment[j]/comments[j])
    if comments[j]>200:
        fakecomratio.append(fakecomment[j]/200)
    if comments[j]==0:
        fakecomratio.append(fakecomment[j]/1)

# %%
print(channelid)
# Out:
# ['UCpwvZwUam-URkxB7g4USKpg', 'UCpKimtjklYBgSKfSJrnXLRA', 'UC_AFL88oKJgUJb0jK_LiOrQ', 'UCJFwiiOMFYGTpWRqzygH-mQ', 'UCdue2nzmoVWUW2i9IJEQw5A', 'UCJFwiiOMFYGTpWRqzygH-mQ', 'UCGMaaZ6r7FGJWhdp8Bn4viw', 'UCSHpzRij8qE1fAwCRlTofpQ', 'UCdYTKpXMnWMAzFi2-agsDCg', 'UCqhnX4jA0A5paNd1v-zEysw', 'UCeNAs9OuE-2DrodEssUCNYA']

# %%
for i in range(len(channelid)):
    request = youtube.channels().list(part="snippet,contentDetails,statistics",id=channelid[i]).execute()    
    s1=request['items'][0]['statistics']['subscriberCount']
    s2=request['items'][0]['snippet']['publishedAt'][:10]
    date.append(s2)
    subscribers.append(s1)

# %%
import pandas as pd
data={'title':title,'liked':liked,'disliked':disliked,'dlratio':dlratio,'subscriberCount':subscribers,'views':views,'comments':comments,'video_id':video_id,'positive_polarity':positive_polarity,'negative_polarity':negative_polarity,'compareposneg':compareposneg,'fakecomment':fakecomment,'fakecomratio':fakecomratio,'category':cat_name,'channel id':channelid,'registration':date}
df=pd.DataFrame(data)#title
df
# Out:
#                                                 title    liked  disliked  \
# 0   Dramatic video: Luxury skyscraper hotel on fir...      535        45
# 1             Criminals Target Olympic Site in Brazil   149375     60047
# 2   Golden Retriever Pokes Head Out From Train Lug...       35         7
# 3            NYC Woman head stuck between train doors       24        18
# 4   Dramatic moment North Korean soldier makes mad...     6637       616
# 5            NYC Woman head stuck between train doors       24        18
# 6                    Dolphin Seen at Mahalaxmi Mumbai       11         0
# 7   Angry mob throwing stones on mumbai local trai...     3286      2200
# 8   Woman carted off by Muslim horde into subway s...       39         7
# 9   GoPro: Backflip Over 72ft Canyon - Kelly McGar...  1361088     48870
# 10  People running from scene of terrorist attack ...        7         4
#
#      dlratio subscriberCount      views  comments     video_id  \
# 0   0.084112         3840000     199383      1018  izNDNHK3_N8
# 1   0.401988           97400   53721207     86830  c0ztLtpuwkM
# 2   0.200000          133000      30443         0  aWpFxEmtIDA
# 3   0.750000            1430      17627        34  t9kfJUQnawU
# 4   0.092813             711    3001695      2313  0fNy_tWYkd4
# 5   0.750000            1430      17627        34  t9kfJUQnawU
# 6   0.000000              18        941         0  XvMoYEUVcB4
# 7   0.669507            4360    2437632       490  lYFpga7kJxE
# 8   0.179487            1570       4624        29  WNjFFTQsIAg
# 9   0.035905         8770000  124052362     40991  x76VEPXYaI0
# 10  0.571429             132      26300        10  VESBrSWm3Yg
#
#     positive_polarity  negative_polarity  compareposneg  fakecomment  \
# 0                  44                 56       0.785714            2
# 1                  20                 80       0.250000            2
# 2                   0                  1       0.000000            0
# 3                   8                 15       0.533333            2
# 4                  37                 63       0.587302            7
# 5                   8                 15       0.533333            2
# 6                   0                  1       0.000000            0
# 7                  11                 89       0.123596            0
# 8                   2                 13       0.153846            0
# 9                  27                 73       0.369863            0
# 10                  0                  4       0.000000            0
#
#     fakecomratio         category                channel id registration
# 0       0.010000  News & Politics  UCpwvZwUam-URkxB7g4USKpg   2007-03-28
# 1       0.010000   People & Blogs  UCpKimtjklYBgSKfSJrnXLRA   2016-02-05
# 2       0.000000    Entertainment  UC_AFL88oKJgUJb0jK_LiOrQ   2008-02-10
# 3       0.058824           Comedy  UCJFwiiOMFYGTpWRqzygH-mQ   2011-10-03
# 4       0.035000  News & Politics  UCdue2nzmoVWUW2i9IJEQw5A   2012-03-04
# 5       0.058824           Comedy  UCJFwiiOMFYGTpWRqzygH-mQ   2011-10-03
# 6       0.000000   People & Blogs  UCGMaaZ6r7FGJWhdp8Bn4viw   2017-12-16
# 7       0.000000  News & Politics  UCSHpzRij8qE1fAwCRlTofpQ   2011-07-09
# 8       0.000000  News & Politics  UCdYTKpXMnWMAzFi2-agsDCg   2014-05-16
# 9       0.000000           Sports  UCqhnX4jA0A5paNd1v-zEysw   2009-03-11
# 10      0.000000   People & Blogs  UCeNAs9OuE-2DrodEssUCNYA   2016-01-22

# %%
df.to_csv('MSRESULT10.csv',index=False)
