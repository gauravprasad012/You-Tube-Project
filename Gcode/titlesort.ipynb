# %%
import pandas as pd

# %%
df=pd.read_csv('final69.csv')

# %%
df
# Out:
#                                                  title   liked  disliked  \
# 0    Sad News For Dharmendra Fans, Dharmendra Death...     788       160
# 1                                     Dharmendra Death      18        18
# 2    Abhishek Bachchan and Shweta Bachchan in Koffe...     801       263
# 3                     How To Get 6 Pack Abs In One Day    3543      3558
# 4                 Dirty Secrets of the Bachchan Family    8671      5610
# ..                                                 ...     ...       ...
# 990  Aishwarya accepts ‘Khajur’ as her son – The Ka...  192121     28859
# 991  Cold War Between Lottery And Sarla - The Kapil...   78208     10173
# 992  England Queen's Wedding Shopping | Sargun Meht...   59635      6190
# 993  Kapil Copies Dr. Gulati's Look - The Kapil Sha...  261516     18796
# 994  Rajesh Arora Hates Rinku's Face - The Kapil Sh...  140719      9489
#
#       dlratio  subscriberCount     views  comments     video_id  \
# ...
